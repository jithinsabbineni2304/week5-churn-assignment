# %% [markdown]
# # Week 5 — Churn Modeling with PyCaret
# (With Explicit Step Labels)

# %%
# Step 1: Install dependencies (run once if needed)
# !pip install -U "pycaret==3.3.2" "pandas<2.2" "scikit-learn<1.5" "imbalanced-learn>=0.10,<0.13"
# Out:
# Requirement already satisfied: pycaret==3.3.2 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (3.3.2)
# Requirement already satisfied: pandas<2.2 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn<1.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (1.4.2)
# Requirement already satisfied: imbalanced-learn<0.13,>=0.10 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (0.12.4)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (9.5.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.26.4)
# Requirement already satisfied: jinja2>=3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.3.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (2.0.5)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.61.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (6.3.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.1.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pycaret==3.3.2) (2.0.4)
# Requirement already satisfied: packaging in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from sktime==0.26.0->pycaret==3.3.2) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from sktime==0.26.0->pycaret==3.3.2) (0.7.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pandas<2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pandas<2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pandas<2.2) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from scikit-learn<1.5) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (3.2.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from category-encoders>=2.4.0->pycaret==3.3.2) (1.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from importlib-metadata>=4.12.0->pycaret==3.3.2) (3.23.0)
# Requirement already satisfied: colorama in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.4.6)
# Requirement already satisfied: decorator in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipython>=5.5.0->pycaret==3.3.2) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret==3.3.2) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.3.2) (0.8.5)
# Requirement already satisfied: choreographer>=1.0.10 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from kaleido>=0.2.1->pycaret==3.3.2) (1.1.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from kaleido>=0.2.1->pycaret==3.3.2) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from kaleido>=0.2.1->pycaret==3.3.2) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from kaleido>=0.2.1->pycaret==3.3.2) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from choreographer>=1.0.10->kaleido>=0.2.1->pycaret==3.3.2) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.3.2) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.3.2) (311)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from numba>=0.55.0->pycaret==3.3.2) (0.44.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from plotly>=5.14.0->pycaret==3.3.2) (2.6.0)
# Requirement already satisfied: dash>=2.11.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.2.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.3.2) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (3.1.3)
# Requirement already satisfied: retrying in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (3.1.4)
# Requirement already satisfied: urllib3 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret==3.3.2) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret==3.3.2) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret==3.3.2) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from requests>=2.27.1->pycaret==3.3.2) (2025.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.3.2) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.3.2) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\jithi\anaconda3\envs\ids101\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret==3.3.2) (0.2.3)

# %%
# Step 2: Configure paths to your dataset files
from pathlib import Path
import pandas as pd

TRAIN_CSV = "cleaned_data.csv"        # Week 2 cleaned dataset
NEW_CSV   = "new_churn_data.csv"      # New dataset for testing
TARGET    = "Churn"                   # Change if your target column differs

print("Training file exists?", Path(TRAIN_CSV).exists())
print("New data file exists?", Path(NEW_CSV).exists())
# Out:
# Training file exists? True
# New data file exists? True

# %%
# Step 3: Load and inspect training data
df = pd.read_csv(TRAIN_CSV)
print("Initial shape:", df.shape)

if TARGET not in df.columns:
    raise ValueError(f"Target column '{TARGET}' not found in training data")

if df[TARGET].dtype == object:
    df[TARGET] = df[TARGET].astype(str).str.strip().str.lower().map({'yes':1,'no':0}).fillna(df[TARGET])
    df[TARGET] = df[TARGET].astype(int)

for id_col in ['customerID','CustomerID','customer_id']:
    if id_col in df.columns:
        df.drop(columns=[id_col], inplace=True)
        print("Dropped identifier:", id_col)

df.head()
# Out:
# Initial shape: (7043, 9)
# Dropped identifier: customerID
#    tenure PhoneService        Contract              PaymentMethod  \
# 0       1           No  Month-to-month           Electronic check
# 1      34          Yes        One year               Mailed check
# 2       2          Yes  Month-to-month               Mailed check
# 3      45           No        One year  Bank transfer (automatic)
# 4       2          Yes  Month-to-month           Electronic check
#
#    MonthlyCharges  TotalCharges  Churn  ChargePerMonth
# 0           29.85         29.85      0       14.925000
# 1           56.95       1889.50      0       53.985714
# 2           53.85        108.15      1       36.050000
# 3           42.30       1840.75      0       40.016304
# 4           70.70        151.65      1       50.550000

# %%
# Step 4: Train and compare models with PyCaret
from pycaret.classification import setup, compare_models, pull, finalize_model, save_model, predict_model

clf = setup(
    data=df,
    target=TARGET,
    session_id=42,
    train_size=0.8,
    normalize=True,
    imputation_type=None,
    use_gpu=False,
    fold=5
)

best_model = compare_models(sort="AUC")
leaderboard = pull()
leaderboard.head(10)
# Out:
# <style type="text/css">
# #T_7e215_row9_col1, #T_7e215_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7e215">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e215_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7e215_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e215_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e215_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7e215_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e215_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7e215_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e215_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7e215_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e215_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7e215_row3_col1" class="data row3 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e215_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7e215_row4_col1" class="data row4 col1" >(7043, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e215_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7e215_row5_col1" class="data row5 col1" >(5634, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e215_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7e215_row6_col1" class="data row6 col1" >(1409, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7e215_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7e215_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7e215_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_7e215_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7e215_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_7e215_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7e215_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_7e215_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7e215_row11_col0" class="data row11 col0" >Maximum one-hot encoding</td>
#       <td id="T_7e215_row11_col1" class="data row11 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7e215_row12_col0" class="data row12 col0" >Encoding method</td>
#       <td id="T_7e215_row12_col1" class="data row12 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7e215_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_7e215_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7e215_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_7e215_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7e215_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7e215_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7e215_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7e215_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7e215_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7e215_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7e215_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7e215_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7e215_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7e215_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7e215_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7e215_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7e215_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7e215_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7e215_row21_col1" class="data row21 col1" >477c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c0bd8 th {
#   text-align: left;
# }
# #T_c0bd8_row0_col0, #T_c0bd8_row0_col3, #T_c0bd8_row0_col4, #T_c0bd8_row0_col5, #T_c0bd8_row1_col0, #T_c0bd8_row1_col1, #T_c0bd8_row1_col2, #T_c0bd8_row1_col3, #T_c0bd8_row1_col4, #T_c0bd8_row1_col5, #T_c0bd8_row1_col6, #T_c0bd8_row1_col7, #T_c0bd8_row2_col0, #T_c0bd8_row2_col1, #T_c0bd8_row2_col2, #T_c0bd8_row2_col3, #T_c0bd8_row2_col4, #T_c0bd8_row2_col5, #T_c0bd8_row2_col6, #T_c0bd8_row2_col7, #T_c0bd8_row3_col0, #T_c0bd8_row3_col1, #T_c0bd8_row3_col2, #T_c0bd8_row3_col3, #T_c0bd8_row3_col5, #T_c0bd8_row3_col6, #T_c0bd8_row3_col7, #T_c0bd8_row4_col0, #T_c0bd8_row4_col1, #T_c0bd8_row4_col2, #T_c0bd8_row4_col3, #T_c0bd8_row4_col4, #T_c0bd8_row4_col5, #T_c0bd8_row4_col6, #T_c0bd8_row4_col7, #T_c0bd8_row5_col0, #T_c0bd8_row5_col1, #T_c0bd8_row5_col2, #T_c0bd8_row5_col3, #T_c0bd8_row5_col4, #T_c0bd8_row5_col5, #T_c0bd8_row5_col6, #T_c0bd8_row5_col7, #T_c0bd8_row6_col0, #T_c0bd8_row6_col1, #T_c0bd8_row6_col2, #T_c0bd8_row6_col3, #T_c0bd8_row6_col4, #T_c0bd8_row6_col6, #T_c0bd8_row6_col7, #T_c0bd8_row7_col0, #T_c0bd8_row7_col1, #T_c0bd8_row7_col2, #T_c0bd8_row7_col3, #T_c0bd8_row7_col4, #T_c0bd8_row7_col5, #T_c0bd8_row7_col6, #T_c0bd8_row7_col7, #T_c0bd8_row8_col0, #T_c0bd8_row8_col1, #T_c0bd8_row8_col2, #T_c0bd8_row8_col4, #T_c0bd8_row8_col5, #T_c0bd8_row8_col6, #T_c0bd8_row8_col7, #T_c0bd8_row9_col0, #T_c0bd8_row9_col1, #T_c0bd8_row9_col2, #T_c0bd8_row9_col3, #T_c0bd8_row9_col4, #T_c0bd8_row9_col5, #T_c0bd8_row9_col6, #T_c0bd8_row9_col7, #T_c0bd8_row10_col0, #T_c0bd8_row10_col1, #T_c0bd8_row10_col2, #T_c0bd8_row10_col3, #T_c0bd8_row10_col4, #T_c0bd8_row10_col5, #T_c0bd8_row10_col6, #T_c0bd8_row10_col7, #T_c0bd8_row11_col0, #T_c0bd8_row11_col1, #T_c0bd8_row11_col2, #T_c0bd8_row11_col3, #T_c0bd8_row11_col4, #T_c0bd8_row11_col5, #T_c0bd8_row11_col6, #T_c0bd8_row11_col7, #T_c0bd8_row12_col0, #T_c0bd8_row12_col1, #T_c0bd8_row12_col2, #T_c0bd8_row12_col3, #T_c0bd8_row12_col4, #T_c0bd8_row12_col5, #T_c0bd8_row12_col6, #T_c0bd8_row12_col7, #T_c0bd8_row13_col0, #T_c0bd8_row13_col1, #T_c0bd8_row13_col2, #T_c0bd8_row13_col3, #T_c0bd8_row13_col4, #T_c0bd8_row13_col5, #T_c0bd8_row13_col6, #T_c0bd8_row13_col7 {
#   text-align: left;
# }
# #T_c0bd8_row0_col1, #T_c0bd8_row0_col2, #T_c0bd8_row0_col6, #T_c0bd8_row0_col7, #T_c0bd8_row3_col4, #T_c0bd8_row6_col5, #T_c0bd8_row8_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c0bd8_row0_col8, #T_c0bd8_row1_col8, #T_c0bd8_row2_col8, #T_c0bd8_row4_col8, #T_c0bd8_row5_col8, #T_c0bd8_row6_col8, #T_c0bd8_row7_col8, #T_c0bd8_row8_col8, #T_c0bd8_row9_col8, #T_c0bd8_row10_col8, #T_c0bd8_row11_col8, #T_c0bd8_row12_col8, #T_c0bd8_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c0bd8_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c0bd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0bd8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c0bd8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c0bd8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c0bd8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c0bd8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c0bd8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c0bd8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c0bd8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c0bd8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0bd8_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_c0bd8_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_c0bd8_row0_col1" class="data row0 col1" >0.7987</td>
#       <td id="T_c0bd8_row0_col2" class="data row0 col2" >0.8392</td>
#       <td id="T_c0bd8_row0_col3" class="data row0 col3" >0.4957</td>
#       <td id="T_c0bd8_row0_col4" class="data row0 col4" >0.6616</td>
#       <td id="T_c0bd8_row0_col5" class="data row0 col5" >0.5662</td>
#       <td id="T_c0bd8_row0_col6" class="data row0 col6" >0.4387</td>
#       <td id="T_c0bd8_row0_col7" class="data row0 col7" >0.4468</td>
#       <td id="T_c0bd8_row0_col8" class="data row0 col8" >0.8380</td>
#     </tr>
#     <tr>
#       <th id="T_c0bd8_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_c0bd8_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c0bd8_row1_col1" class="data row1 col1" >0.7902</td>
#       <td id="T_c0bd8_row1_col2" class="data row1 col2" >0.8370</td>
#       <td id="T_c0bd8_row1_col3" class="data row1 col3" >0.4856</td>
#       <td id="T_c0bd8_row1_col4" class="data row1 col4" >0.6377</td>
#       <td id="T_c0bd8_row1_col5" class="data row1 col5" >0.5510</td>
#       <td id="T_c0bd8_row1_col6" class="data row1 col6" >0.4174</td>
#       <td id="T_c0bd8_row1_col7" class="data row1 col7" >0.4243</td>
#       <td id="T_c0bd8_row1_col8" class="data row1 col8" >0.4480</td>
#     </tr>
#     <tr>
#       <th id="T_c0bd8_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_c0bd8_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_c0bd8_row2_col1" class="data row2 col1" >0.7932</td>
#       <td id="T_c0bd8_row2_col2" class="data row2 col2" >0.8340</td>
#       <td id="T_c0bd8_row2_col3" class="data row2 col3" >0.4983</td>
#       <td id="T_c0bd8_row2_col4" class="data row2 col4" >0.6436</td>
#       <td id="T_c0bd8_row2_col5" class="data row2 col5" >0.5612</td>
#       <td id="T_c0bd8_row2_col6" class="data row2 col6" >0.4289</td>
#       <td id="T_c0bd8_row2_col7" class="data row2 col7" >0.4352</td>
#       <td id="T_c0bd8_row2_col8" class="data row2 col8" >0.1800</td>
#     </tr>
#     <tr>
#       <th id="T_c0bd8_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_c0bd8_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_c0bd8_row3_col1" class="data row3 col1" >0.7964</td>
#       <td id="T_c0bd8_row3_col2" class="data row3 col2" >0.8326</td>
#       <td id="T_c0bd8_row3_col3" class="data row3 col3" >0.4381</td>
#       <td id="T_c0bd8_row3_col4" class="data row3 col4" >0.6814</td>
#       <td id="T_c0bd8_row3_col5" class="data row3 col5" >0.5328</td>
#       <td id="T_c0bd8_row3_col6" class="data row3 col6" >0.4105</td>
#       <td id="T_c0bd8_row3_col7" class="data row3 col7" >0.4271</td>
#       <td id="T_c0bd8_row3_col8" class="data row3 col8" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_c0bd8_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_c0bd8_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_c0bd8_row4_col1" class="data row4 col1" >0.7964</td>
#       <td id="T_c0bd8_row4_col2" class="data row4 col2" >0.8326</td>
#       <td id="T_c0bd8_row4_col3" class="data row4 col3" >0.4883</td>
#       <td id="T_c0bd8_row4_col4" class="data row4 col4" >0.6574</td>
#       <td id="T_c0bd8_row4_col5" class="data row4 col5" >0.5598</td>
#       <td id="T_c0bd8_row4_col6" class="data row4 col6" >0.4312</td>
#       <td id="T_c0bd8_row4_col7" class="data row4 col7" >0.4396</td>
#       <td id="T_c0bd8_row4_col8" class="data row4 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_c0bd8_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_c0bd8_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c0bd8_row5_col1" class="data row5 col1" >0.7817</td>
#       <td id="T_c0bd8_row5_col2" class="data row5 col2" >0.8261</td>
#       <td id="T_c0bd8_row5_col3" class="data row5 col3" >0.5043</td>
#       <td id="T_c0bd8_row5_col4" class="data row5 col4" >0.6070</td>
#       <td id="T_c0bd8_row5_col5" class="data row5 col5" >0.5507</td>
#       <td id="T_c0bd8_row5_col6" class="data row5 col6" >0.4081</td>
#       <td id="T_c0bd8_row5_col7" class="data row5 col7" >0.4114</td>
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7987  0.8392  0.4957  0.6616
# gbc          Gradient Boosting Classifier    0.7902  0.8370  0.4856  0.6377
# ada                  Ada Boost Classifier    0.7932  0.8340  0.4983  0.6436
# ridge                    Ridge Classifier    0.7964  0.8326  0.4381  0.6814
# lda          Linear Discriminant Analysis    0.7964  0.8326  0.4883  0.6574
# lightgbm  Light Gradient Boosting Machine    0.7817  0.8261  0.5043  0.6070
# qda       Quadratic Discriminant Analysis    0.7323  0.8245  0.7659  0.5022
# svm                   SVM - Linear Kernel    0.7845  0.8162  0.4910  0.6274
# nb                            Naive Bayes    0.6904  0.8108  0.8314  0.4549
# rf               Random Forest Classifier    0.7730  0.7981  0.4883  0.5878
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.5662  0.4387  0.4468     0.838
# gbc       0.5510  0.4174  0.4243     0.448
# ada       0.5612  0.4289  0.4352     0.180
# ridge     0.5328  0.4105  0.4271     0.046
# lda       0.5598  0.4312  0.4396     0.056
# lightgbm  0.5507  0.4081  0.4114     0.550
# qda       0.6032  0.4158  0.4402     0.052
# svm       0.5418  0.4059  0.4158     0.056
# nb        0.5879  0.3726  0.4163     1.206
# rf        0.5332  0.3849  0.3880     0.270

# %%
# Step 5: Finalize best model and save it
final_model = finalize_model(best_model)
predict_model(final_model).head()

MODEL_NAME = "week5_churn_model"
save_model(final_model, MODEL_NAME)
print("Model saved to:", MODEL_NAME + ".pkl")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b98b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b98b6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b98b6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b98b6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b98b6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b98b6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b98b6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b98b6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b98b6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b98b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b98b6_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b98b6_row0_col1" class="data row0 col1" >0.7921</td>
#       <td id="T_b98b6_row0_col2" class="data row0 col2" >0.8410</td>
#       <td id="T_b98b6_row0_col3" class="data row0 col3" >0.4706</td>
#       <td id="T_b98b6_row0_col4" class="data row0 col4" >0.6494</td>
#       <td id="T_b98b6_row0_col5" class="data row0 col5" >0.5457</td>
#       <td id="T_b98b6_row0_col6" class="data row0 col6" >0.4153</td>
#       <td id="T_b98b6_row0_col7" class="data row0 col7" >0.4244</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# Model saved to: week5_churn_model.pkl

# %%
# Step 6: Predict on new data (with ChargePerMonth fix)
from pycaret.classification import load_model, predict_model

new_df = pd.read_csv(NEW_CSV)

# Ensure engineered feature exists
if 'TotalCharges' in new_df.columns and 'tenure' in new_df.columns:
    new_df['TotalCharges'] = pd.to_numeric(new_df['TotalCharges'], errors='coerce')
    new_df['tenure'] = pd.to_numeric(new_df['tenure'], errors='coerce').fillna(0)
    if 'ChargePerMonth' not in new_df.columns:
        new_df['ChargePerMonth'] = new_df['TotalCharges'] / (new_df['tenure'] + 1.0)

for id_col in ['customerID','CustomerID','customer_id']:
    if id_col in new_df.columns:
        new_df.drop(columns=[id_col], inplace=True)

model = load_model(MODEL_NAME)
preds = predict_model(model, data=new_df, raw_score=True)
preds.head()
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0      22             1         0              2       97.400002
# 1       8             0         1              1       77.300003
# 2      28             1         0              0       28.250000
# 3      62             1         0              2      101.699997
# 4      10             0         0              1       51.150002
#
#    TotalCharges  charge_per_tenure  ChargePerMonth  prediction_label  \
# 0    811.700012          36.895454       35.291306                 1
# 1   1701.949951         212.743744      189.105560                 0
# 2    250.899994           8.960714        8.651724                 0
# 3   3106.560059          50.105808       49.310474                 1
# 4   3440.969971         344.096985      312.815460                 0
#
#    prediction_score_0  prediction_score_1
# 0              0.0659              0.9341
# 1              0.9699              0.0301
# 2              0.6897              0.3103
# 3              0.2296              0.7704
# 4              0.9999              0.0001

# %%
# Step 7: Quick evaluation on provided true labels [1, 0, 0, 1, 0]
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import numpy as np

true_labels = [1, 0, 0, 1, 0]
y_true = np.array(true_labels)

# Try to find prediction column
label_col = None
for c in preds.columns:
    if c.lower() in ["label","prediction_label","predicted_label"]:
        label_col = c
        break

if label_col is None:
    if 'Score_1' in preds.columns:
        preds['PredLabel'] = (preds['Score_1'] >= 0.5).astype(int)
        label_col = 'PredLabel'

if label_col:
    y_pred = preds[label_col].astype(int).values[:len(y_true)]
    print("Confusion matrix:\n", confusion_matrix(y_true,y_pred))
    print("\nClassification report:\n", classification_report(y_true,y_pred,digits=3))

    if 'Score_1' in preds.columns:
        auc_val = roc_auc_score(y_true, preds['Score_1'].values[:len(y_true)])
        print("AUC:", round(auc_val,3))
else:
    print("Could not infer prediction labels")
# Out:
# Confusion matrix:
#  [[3 0]
#  [0 2]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000         3
#            1      1.000     1.000     1.000         2
#
#     accuracy                          1.000         5
#    macro avg      1.000     1.000     1.000         5
# weighted avg      1.000     1.000     1.000         5

# %% [markdown]
# Summary:
# In this project, I applied PyCaret to the cleaned Week 2 churn dataset to identify the best-performing classification model for predicting customer churn, using AUC as the primary metric since it balances predictive power across imbalanced classes. After comparing multiple algorithms, I finalized and saved the best model, then created a reusable Python module (churn_predictor.py) to streamline predictions on new data. For evaluation, I tested the model on new_churn_data.csv, where I engineered the ChargePerMonth feature (TotalCharges divided by tenure plus one) to ensure consistency with the training features. The predictions generated churn probabilities for each record, and I compared them with the provided true labels [1, 0, 0, 1, 0] to compute confusion matrix, classification report, and AUC. The results highlighted the model’s ability to capture churn patterns, though adjustments to probability thresholds or recall-focused metrics may further improve performance.
#
# Citation:
# 1. Chatgpt
# 2. Copilot
